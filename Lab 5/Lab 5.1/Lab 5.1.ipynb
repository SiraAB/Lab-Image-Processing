# %%
#Import Libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt

from keras import Model, Input
import keras.utils as image
from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, UpSampling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers

from tensorflow.keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split

#Read Image
img = cv2.imread('grid.jpg')

#Define Resize Factor
reduce_factor = [2, 4, 8]
scale_factor = [1/factor for factor in reduce_factor]

#Define interpolation method
interpolation_method = [cv2.INTER_NEAREST, cv2.INTER_LINEAR, cv2.INTER_CUBIC, cv2.INTER_AREA]

#Display results using each scale_factor & Interpolation methods
# cv2.resize(img, (0, 0), fx=scale_factor[i], fy=scale_factor[i], interpolation=interpolation_method[j])

#Display results using each scale_factor & Interpolation methods
for i in range(3):
    for j in range(4):
        cv2.resize(img, (0, 0), fx=scale_factor[i], fy=scale_factor[i], interpolation=interpolation_method[j])
        img_scaled = cv2.resize(img, None, fx=scale_factor[i], fy=scale_factor[i], interpolation=interpolation_method[j])
        plt.subplot(3, 4, i*4+j+1)
        plt.imshow(img_scaled)
        # plt.title('Scale Factor: '+str(scale_factor[i])+'\nInterpolation: '+str(interpolation_method[j]))
        plt.xticks([])
        plt.yticks([])
plt.show()

# %%
#Import Libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt

from keras import Model, Input
import keras.utils as image
from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, UpSampling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import optimizers

from tensorflow.keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split

#Read Image
img = cv2.imread('person.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Define Resize Factor
reduce_factor = [2, 8, 15]
scale_factor = [1/factor for factor in reduce_factor]

#Define interpolation method
interpolation_method = [cv2.INTER_NEAREST, cv2.INTER_LINEAR, cv2.INTER_CUBIC, cv2.INTER_AREA]

#Display results using each scale_factor & Interpolation methods
# cv2.resize(img, (0, 0), fx=scale_factor[i], fy=scale_factor[i], interpolation=interpolation_method[j])

#Display results using each scale_factor & Interpolation methods
for i in range(3):
    for j in range(4):
        cv2.resize(img, (0, 0), fx=scale_factor[i], fy=scale_factor[i], interpolation=interpolation_method[j])
        img_scaled = cv2.resize(img, None, fx=scale_factor[i], fy=scale_factor[i], interpolation=interpolation_method[j])
        plt.subplot(3, 4, i*4+j+1)
        plt.imshow(img_scaled)
        # plt.title('Scale Factor: '+str(scale_factor[i])+'\nInterpolation: '+str(interpolation_method[j]))
        plt.xticks([])
        plt.yticks([])
plt.show()
